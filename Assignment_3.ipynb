# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('dirty_dataset.csv')
df
# Out:
#        employee_id      name    age   salary   join_date   department  gender  \
# 0            12369  Hasan D.  200.0    35149  2023-05-30        SALES     Man
# 1             7361  Grace P.    NaN    77836  2017-02-27  Engineering  FEMALE
# 2             3446    Eve D.   20.0    35404  2022-01-18           hr    male
# 3            18416  Diana E.   47.0   107375  2017-04-15    Marketing    Male
# 4            13677    Ira W.   64.0    55962  2021-11-02        SALES       F
# ...            ...       ...    ...      ...         ...          ...     ...
# 20295        19842  Frank N.   27.0  9999999  2010-06-21  engineering  Female
# 20296         1769  Frank N.   45.0    31616  2021-01-11           hr       F
# 20297         9930  Hasan A.   30.0    70125  2013-07-07  Engineering   Woman
# 20298         3241  Frank D.   58.0    40120  2022-03-25        SALES       M
# 20299        13498  Alice X.    NaN   114722  2023-08-12           HR     Man
#
#               country        city weight_kg is_active  \
# 0             America      Sylhet     118.4         0
# 1             America  Chittagong      71kg      True
# 2          BANGLADESH   Chitagong      98.7     False
# 3                U.K.      Khulna       NaN     false
# 4      United Kingdom       Dhaka      83.5     false
# ...               ...         ...       ...       ...
# 20295            U.K.  Chittagong      93.7     False
# 20296            U.K.      Khulna       NaN     False
# 20297              bd      Khulna     116.3      True
# 20298              UK    Rajshahi      72.0      True
# 20299              UK      Khulna      74.0     False
#
#                                        review    price  weight_kg_duplicate  \
# 0                       Good value for money.   219.18                  NaN
# 1               Product met all expectations.   329.26                  NaN
# 2            Very satisfied with the quality.    438.6                  NaN
# 3      Delivery was fast and packaging great.   238.03                  NaN
# 4         Would buy again without hesitation.      9.4                  NaN
# ...                                       ...      ...                  ...
# 20295  Delivery was fast and packaging great.  $199.19                  NaN
# 20296           Product met all expectations.   223.39                  NaN
# 20297     Would buy again without hesitation.    68.16                  NaN
# 20298                                     NaN    90.83                  NaN
# 20299                                     NaN   142.13                  NaN
#
#        target
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 20295       0
# 20296       0
# 20297       0
# 20298       0
# 20299       0
#
# [20300 rows x 15 columns]

# %%
df.shape
# Out:
# (20300, 15)

# %%
df1=df.copy()

# %%
df.dtypes
# Out:
# employee_id              int64
# name                    object
# age                    float64
# salary                  object
# join_date               object
# department              object
# gender                  object
# country                 object
# city                    object
# weight_kg               object
# is_active               object
# review                  object
# price                   object
# weight_kg_duplicate    float64
# target                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# employee_id                0
# name                       0
# age                      621
# salary                   610
# join_date                810
# department               857
# gender                  1632
# country                  608
# city                     604
# weight_kg                643
# is_active                586
# review                  1465
# price                    446
# weight_kg_duplicate    20300
# target                     0
# dtype: int64

# %% [markdown]
# ## Task 01: Missing Values (NaN, Empty Strings)
#
# **Problem:**
# A column may have missing values (NaN or empty strings).
#
# These missing values create issues in data visualization.

# %%
df.isnull().sum()
# Out:
# employee_id                0
# name                       0
# age                      621
# salary                   610
# join_date                810
# department               857
# gender                  1632
# country                  608
# city                     604
# weight_kg                643
# is_active                586
# review                  1465
# price                    446
# weight_kg_duplicate    20300
# target                     0
# dtype: int64

# %%
df
# Out:
#        employee_id      name    age   salary   join_date   department  gender  \
# 0            12369  Hasan D.  200.0    35149  2023-05-30        SALES     Man
# 1             7361  Grace P.    NaN    77836  2017-02-27  Engineering  FEMALE
# 2             3446    Eve D.   20.0    35404  2022-01-18           hr    male
# 3            18416  Diana E.   47.0   107375  2017-04-15    Marketing    Male
# 4            13677    Ira W.   64.0    55962  2021-11-02        SALES       F
# ...            ...       ...    ...      ...         ...          ...     ...
# 20295        19842  Frank N.   27.0  9999999  2010-06-21  engineering  Female
# 20296         1769  Frank N.   45.0    31616  2021-01-11           hr       F
# 20297         9930  Hasan A.   30.0    70125  2013-07-07  Engineering   Woman
# 20298         3241  Frank D.   58.0    40120  2022-03-25        SALES       M
# 20299        13498  Alice X.    NaN   114722  2023-08-12           HR     Man
#
#               country        city weight_kg is_active  \
# 0             America      Sylhet     118.4         0
# 1             America  Chittagong      71kg      True
# 2          BANGLADESH   Chitagong      98.7     False
# 3                U.K.      Khulna       NaN     false
# 4      United Kingdom       Dhaka      83.5     false
# ...               ...         ...       ...       ...
# 20295            U.K.  Chittagong      93.7     False
# 20296            U.K.      Khulna       NaN     False
# 20297              bd      Khulna     116.3      True
# 20298              UK    Rajshahi      72.0      True
# 20299              UK      Khulna      74.0     False
#
#                                        review    price  weight_kg_duplicate  \
# 0                       Good value for money.   219.18                  NaN
# 1               Product met all expectations.   329.26                  NaN
# 2            Very satisfied with the quality.    438.6                  NaN
# 3      Delivery was fast and packaging great.   238.03                  NaN
# 4         Would buy again without hesitation.      9.4                  NaN
# ...                                       ...      ...                  ...
# 20295  Delivery was fast and packaging great.  $199.19                  NaN
# 20296           Product met all expectations.   223.39                  NaN
# 20297     Would buy again without hesitation.    68.16                  NaN
# 20298                                     NaN    90.83                  NaN
# 20299                                     NaN   142.13                  NaN
#
#        target
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 20295       0
# 20296       0
# 20297       0
# 20298       0
# 20299       0
#
# [20300 rows x 15 columns]

# %%
df['salary']=pd.to_numeric(df['salary'],errors='coerce')

# %%
df['salary']
# Out:
# 0          35149.0
# 1          77836.0
# 2          35404.0
# 3         107375.0
# 4          55962.0
#            ...
# 20295    9999999.0
# 20296      31616.0
# 20297      70125.0
# 20298      40120.0
# 20299     114722.0
# Name: salary, Length: 20300, dtype: float64

# %%
df['price']
# Out:
# 0         219.18
# 1         329.26
# 2          438.6
# 3         238.03
# 4            9.4
#           ...
# 20295    $199.19
# 20296     223.39
# 20297      68.16
# 20298      90.83
# 20299     142.13
# Name: price, Length: 20300, dtype: object

# %%
df["price"] = (
    df["price"]
    .astype(str)
    .str.replace("$", "", regex=False)
)

df["price"] = pd.to_numeric(df["price"], errors="coerce")

# %%
df['price']
# Out:
# 0        219.18
# 1        329.26
# 2        438.60
# 3        238.03
# 4          9.40
#           ...
# 20295    199.19
# 20296    223.39
# 20297     68.16
# 20298     90.83
# 20299    142.13
# Name: price, Length: 20300, dtype: float64

# %%
df['weight_kg']
# Out:
# 0        118.4
# 1         71kg
# 2         98.7
# 3          NaN
# 4         83.5
#          ...
# 20295     93.7
# 20296      NaN
# 20297    116.3
# 20298     72.0
# 20299     74.0
# Name: weight_kg, Length: 20300, dtype: object

# %%
df["weight_kg"] = (
    df["weight_kg"]
    .astype(str)
    .str.replace("kg", "", regex=False)
)

# %%
df["weight_kg"] = pd.to_numeric(df["weight_kg"], errors="coerce")

# %%
df["age"] = df["age"].fillna(df["age"].median())
df["salary"] = df["salary"].fillna(df["salary"].median())
df["price"] = df["price"].fillna(df["price"].median())
df["weight_kg"] = df["weight_kg"].fillna(df["weight_kg"].median())

# %%
df.isnull().sum()
# Out:
# employee_id                0
# name                       0
# age                        0
# salary                     0
# join_date                810
# department               857
# gender                  1632
# country                  608
# city                     604
# weight_kg                  0
# is_active                586
# review                  1465
# price                      0
# weight_kg_duplicate    20300
# target                     0
# dtype: int64

# %%
df['department']
# Out:
# 0              SALES
# 1        Engineering
# 2                 hr
# 3          Marketing
# 4              SALES
#             ...
# 20295    engineering
# 20296             hr
# 20297    Engineering
# 20298          SALES
# 20299             HR
# Name: department, Length: 20300, dtype: object

# %%
df['department']=df['department'].fillna(df['department'].mode()[0])

# %%
df['department'].isnull().sum()
# Out:
# 0

# %%
df['gender']
# Out:
# 0           Man
# 1        FEMALE
# 2          male
# 3          Male
# 4             F
#           ...
# 20295    Female
# 20296         F
# 20297     Woman
# 20298         M
# 20299       Man
# Name: gender, Length: 20300, dtype: object

# %%
df['gender']=df['gender'].fillna(df['gender'].mode()[0])

# %%
df['gender'].isnull().sum()
# Out:
# 0

# %%
df['country']
# Out:
# 0               America
# 1               America
# 2            BANGLADESH
# 3                  U.K.
# 4        United Kingdom
#               ...
# 20295              U.K.
# 20296              U.K.
# 20297                bd
# 20298                UK
# 20299                UK
# Name: country, Length: 20300, dtype: object

# %%
df['country']=df['country'].fillna(df['country'].mode()[0])

# %%
df['country'].isnull().sum()
# Out:
# 0

# %%
df['city']=df['city'].fillna(df['city'].mode()[0])

# %%
df.dtypes
# Out:
# employee_id              int64
# name                    object
# age                    float64
# salary                 float64
# join_date               object
# department              object
# gender                  object
# country                 object
# city                    object
# weight_kg              float64
# is_active               object
# review                  object
# price                  float64
# weight_kg_duplicate    float64
# target                   int64
# dtype: object

# %%
df['join_date']
# Out:
# 0        2023-05-30
# 1        2017-02-27
# 2        2022-01-18
# 3        2017-04-15
# 4        2021-11-02
#             ...
# 20295    2010-06-21
# 20296    2021-01-11
# 20297    2013-07-07
# 20298    2022-03-25
# 20299    2023-08-12
# Name: join_date, Length: 20300, dtype: object

# %%
df["join_date"] = pd.to_datetime(
    df["join_date"],
    errors="coerce"
)

# %%
df["join_date"] = df["join_date"].fillna(df["join_date"].mode()[0])

# %%
df["review"] = df["review"].fillna("No Review")

# %%
df['is_active']
# Out:
# 0            0
# 1         True
# 2        False
# 3        false
# 4        false
#          ...
# 20295    False
# 20296    False
# 20297     True
# 20298     True
# 20299    False
# Name: is_active, Length: 20300, dtype: object

# %%
df["is_active"] = df["is_active"].map({
    "True":True,
    "False":False
})

# %%
df['is_active']=df['is_active'].fillna(False)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11212\4292727086.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['is_active']=df['is_active'].fillna(False)

# %%
df.isnull().sum()
# Out:
# employee_id                0
# name                       0
# age                        0
# salary                     0
# join_date                  0
# department                 0
# gender                     0
# country                    0
# city                       0
# weight_kg                  0
# is_active                  0
# review                     0
# price                      0
# weight_kg_duplicate    20300
# target                     0
# dtype: int64

# %%
df.drop(columns=['weight_kg_duplicate'], inplace=True)

# %%
df.isnull().sum()
# Out:
# employee_id    0
# name           0
# age            0
# salary         0
# join_date      0
# department     0
# gender         0
# country        0
# city           0
# weight_kg      0
# is_active      0
# review         0
# price          0
# target         0
# dtype: int64

# %% [markdown]
# ## Solutions
#
# Drop rows
#
# Drop columns
#
# Mean Imputation
#
# Median Imputation
#
# Mode Imputation
#
# Forward Fill
#
# Backward Fill

# %% [markdown]
# ## Task 02 :Duplicate Rows
#
# **Problem:**
#
# Same type rows consume memory which is bad and unnecessary for our analysis.
#
# So, we have to drop duplicate rows.

# %%
df.duplicated().sum()
# Out:
# 300

# %%
df[df.duplicated()]
# Out:
#        employee_id        name    age    salary  join_date   department  \
# 1302         10364    Frank O.   24.0  112578.0 2010-09-10           HR
# 1834         16035    Hasan V.   53.0    -500.0 2017-03-01    Marketing
# 2338         12369    Hasan D.  200.0   35149.0 2023-05-30        SALES
# 2469         13108    Diana V.   43.0   88859.0 2023-06-09    Marketing
# 2784          7983    Grace G.   32.0   75294.0 2023-06-09  engineering
# ...            ...         ...    ...       ...        ...          ...
# 20110        13509  Charlie S.   34.0  106326.0 2016-06-20       Finace
# 20140         2388      Eve A.   35.0   98091.0 2017-04-22        SALES
# 20154         2689     John O.   46.0   45615.0 2023-06-09           hr
# 20173         5188  Charlie J.   46.0   75294.0 2017-04-03           HR
# 20227         4518    Grace R.   54.0   66484.0 2023-06-09    Marketing
#
#        gender        country        city  weight_kg  is_active  \
# 1302        M             BD        Dhka       95.8       True
# 1834   female     BANGLADESH  Chittagong       48.2      False
# 2338      Man        America      Sylhet      118.4      False
# 2469     Male  United States      Khulna       73.8       True
# 2784      Man           U.K.      Khulna       60.2       True
# ...       ...            ...         ...        ...        ...
# 20110     Man          U.S.A      Slyhet      112.3      False
# 20140       M        America      Slyhet       90.4      False
# 20154       F            usa    Rajshahi      118.0      False
# 20173    Male     BANGLADESH  Chittagong       73.0       True
# 20227       M     BANGLADESH      Khulna      116.2       True
#
#                                        review   price  target
# 1302   Delivery was fast and packaging great.   22.75       0
# 1834            Product met all expectations.  385.13       0
# 2338                    Good value for money.  219.18       0
# 2469                                     good  430.17       0
# 2784     Excellent product, highly recommend!  237.72       0
# ...                                       ...     ...     ...
# 20110                                    fine  340.03       0
# 20140                   Good value for money.  451.34       0
# 20154     Would buy again without hesitation.  341.28       0
# 20173                                     bad  419.32       0
# 20227           Product met all expectations.  249.01       0
#
# [300 rows x 14 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df1.shape
# Out:
# (20300, 15)

# %%
df.shape
# Out:
# (20000, 14)

# %%
df2=df.copy()

# %% [markdown]
# **Solutions:**
#
#  Run df.duplicated().sum() to count duplicates.
#
#  Preview duplicates: df[df.duplicated()]
#
#  Remove duplicates: df.drop_duplicates(inplace=True)
#
#  Verify: compare df.shape before and after.
#
#
# Finally ,duplicate rows was no more

# %% [markdown]
# ## Task 03 Duplicate IDs
#
# **Problem**
#
# In a particular column there might be duplicate rows.
#
# It creates memory loss.

# %%
df['employee_id'].duplicated().sum()
# Out:
# 199

# %%
df[df['employee_id'].duplicated(keep=False)]
# Out:
#        employee_id        name   age    salary  join_date   department  \
# 29             250    Frank U.  56.0   90635.0 2013-05-12        Sales
# 40              49     John L.  58.0   50810.0 2024-07-22           hr
# 75              48      Ira E.   0.0  101013.0 2013-08-28  engineering
# 196            436  Charlie S.  29.0   54295.0 2020-08-27     Mrketing
# 270             86      Bob U.  36.0   61688.0 2023-06-09  engineering
# ...            ...         ...   ...       ...        ...          ...
# 20016          207      Bob M.  63.0   73657.0 2013-10-08     Mrketing
# 20072          435  Charlie U.  31.0  112727.0 2016-04-15  engineering
# 20104          427    Frank U.  33.0   35686.0 2014-03-21     Mrketing
# 20267           35      Eve L.  55.0   40160.0 2015-12-13      Finance
# 20289          289    Frank C.  58.0   95829.0 2011-10-28           HR
#
#        gender        country         city  weight_kg  is_active  \
# 29       male     Bangladesh        Dhaka      107.3      False
# 40     FEMALE           U.K.       Dhakka      108.8      False
# 75       MALE             BD       Dhakka      115.0      False
# 196         M             us  Chittagongg       75.9      False
# 270         M             bd       Sylhet       91.7      False
# ...       ...            ...          ...        ...        ...
# 20016       M            USA     Rajshahi      125.5      False
# 20072    MALE           U.K.     Rajshahi      119.0      False
# 20104       M            usa     Rajshahi       73.8       True
# 20267    Male           U.K.        Dhaka       61.0       True
# 20289   Woman  United States       Khulna       93.2       True
#
#                                      review   price  target
# 29      Would buy again without hesitation.  342.24       1
# 40     Excellent product, highly recommend!   83.46       0
# 75                    Good value for money.  318.78       0
# 196           Product met all expectations.  265.25       0
# 270                                      na  167.05       0
# ...                                     ...     ...     ...
# 20016      Very satisfied with the quality.  167.18       0
# 20072                 Good value for money.  242.44       0
# 20104                 Good value for money.  396.43       0
# 20267      Very satisfied with the quality.  106.40       0
# 20289      Very satisfied with the quality.  123.17       0
#
# [353 rows x 14 columns]

# %%
df.drop_duplicates(subset=['employee_id'], keep='first')
# Out:
#        employee_id      name    age     salary  join_date   department  \
# 0            12369  Hasan D.  200.0    35149.0 2023-05-30        SALES
# 1             7361  Grace P.   41.0    77836.0 2017-02-27  Engineering
# 2             3446    Eve D.   20.0    35404.0 2022-01-18           hr
# 3            18416  Diana E.   47.0   107375.0 2017-04-15    Marketing
# 4            13677    Ira W.   64.0    55962.0 2021-11-02        SALES
# ...            ...       ...    ...        ...        ...          ...
# 20295        19842  Frank N.   27.0  9999999.0 2010-06-21  engineering
# 20296         1769  Frank N.   45.0    31616.0 2021-01-11           hr
# 20297         9930  Hasan A.   30.0    70125.0 2013-07-07  Engineering
# 20298         3241  Frank D.   58.0    40120.0 2022-03-25        SALES
# 20299        13498  Alice X.   41.0   114722.0 2023-08-12           HR
#
#        gender         country        city  weight_kg  is_active  \
# 0         Man         America      Sylhet      118.4      False
# 1      FEMALE         America  Chittagong       71.0       True
# 2        male      BANGLADESH   Chitagong       98.7      False
# 3        Male            U.K.      Khulna       86.8      False
# 4           F  United Kingdom       Dhaka       83.5      False
# ...       ...             ...         ...        ...        ...
# 20295  Female            U.K.  Chittagong       93.7      False
# 20296       F            U.K.      Khulna       86.8      False
# 20297   Woman              bd      Khulna      116.3       True
# 20298       M              UK    Rajshahi       72.0       True
# 20299     Man              UK      Khulna       74.0      False
#
#                                        review   price  target
# 0                       Good value for money.  219.18       0
# 1               Product met all expectations.  329.26       0
# 2            Very satisfied with the quality.  438.60       0
# 3      Delivery was fast and packaging great.  238.03       0
# 4         Would buy again without hesitation.    9.40       0
# ...                                       ...     ...     ...
# 20295  Delivery was fast and packaging great.  199.19       0
# 20296           Product met all expectations.  223.39       0
# 20297     Would buy again without hesitation.   68.16       0
# 20298                               No Review   90.83       0
# 20299                               No Review  142.13       0
#
# [19801 rows x 14 columns]

# %%
df['employee_id'] = range(1, len(df)+1)

# %%
assert df['employee_id'].duplicated().sum() == 0

# %% [markdown]
# **Solution**
#
#  Count: df['employee_id'].duplicated().sum()
#
# View: df[df['employee_id'].duplicated(keep=False)]
#
# Option A: keep first occurrence — df.drop_duplicates(subset=['employee_id'], keep='first')
#
#  Option B: assign new unique IDs — df['employee_id'] = range(1, len(df)+1)
#
#  Verify: assert df['employee_id'].duplicated().sum() == 0

# %% [markdown]
# ## Task 04: Wrong Date Formats
#
# **Problem:**
#
# 5 mixed formats: YYYY-MM-DD, DD/MM/YYYY, MM-DD-YYYY, DD-Mon-YYYY
#
# Because of this we can't find which was date ,which was month ,which was year.

# %%
df['join_date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## Solution
#
# Check dtype: df['join_date'].dtype — will be object.
#
# Convert: pd.to_datetime(df['join_date'], infer_datetime_format=True, errors='coerce')
#
# errors='coerce' turns unrecognized formats into NaT.
#
# Handle NaT values: fill with median date.
#
# Standardize output: df['join_date'].dt.strftime('%Y-%m-%d')
#
# Verify dtype: df['join_date'].dtype — should be datetime64.
#
# Already this was done in the above.

# %% [markdown]
# ## Task 05 :Numeric Stored as String
#
# **Problem**
#
# In this case ,we cannot do any mathematical operation if the numerical column is treated as string/obj.

# %%
df['salary'].dtype
# Out:
# dtype('float64')

# %%
df['weight_kg'].dtype
# Out:
# dtype('float64')

# %%
df['price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Already done above
