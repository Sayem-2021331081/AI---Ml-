# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('dirty_dataset.csv')
df.head(10)
# Out:
#    employee_id        name    age  salary   join_date   department  gender  \
# 0        12369    Hasan D.  200.0   35149  2023-05-30        SALES     Man
# 1         7361    Grace P.    NaN   77836  2017-02-27  Engineering  FEMALE
# 2         3446      Eve D.   20.0   35404  2022-01-18           hr    male
# 3        18416    Diana E.   47.0  107375  2017-04-15    Marketing    Male
# 4        13677      Ira W.   64.0   55962  2021-11-02        SALES       F
# 5          458    Frank Y.   38.0   88527  2022-08-16     Mrketing    male
# 6        16484     John Q.   25.0  109079  2020-09-10           hr   Woman
# 7        12951  Charlie K.   22.0  $91118  2010-01-12       Finace       F
# 8        13108    Diana V.   43.0   88859  21/07/2016    Marketing    Male
# 9        14925    Alice C.    0.0   46627  2012-01-12        Sales  FEMALE
#
#           country        city weight_kg is_active  \
# 0         America      Sylhet     118.4         0
# ...

# %%
df.tail(10)
# Out:
#        employee_id        name   age   salary   join_date   department  \
# 20290        16444  Charlie I.  60.0    93596  2011-01-24          NaN
# 20291         8369     John W.  24.0    95199  2024-03-28           hr
# 20292        16834    Grace F.  50.0   111758  2019-02-04  Engineering
# 20293        12274      Eve F.  50.0    32285  2016-03-21     Mrketing
# 20294        16440  Charlie W.  37.0    46333  01-27-2016           hr
# 20295        19842    Frank N.  27.0  9999999  2010-06-21  engineering
# 20296         1769    Frank N.  45.0    31616  2021-01-11           hr
# 20297         9930    Hasan A.  30.0    70125  2013-07-07  Engineering
# 20298         3241    Frank D.  58.0    40120  2022-03-25        SALES
# 20299        13498    Alice X.   NaN   114722  2023-08-12           HR
#
#        gender     country        city weight_kg is_active  \
# 20290   Woman  BANGLADESH  Chittagong     116.2      True
# 20291     NaN        U.K.      Khulna      83kg      True
# ...

# %%
df.isnull().sum()
# Out:
# employee_id                0
# name                       0
# age                      621
# salary                   610
# join_date                810
# department               857
# gender                  1632
# country                  608
# city                     604
# weight_kg                643
# is_active                586
# review                  1465
# price                    446
# weight_kg_duplicate    20300
# target                     0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# employee_id              0.000000
# name                     0.000000
# age                      3.059113
# salary                   3.004926
# join_date                3.990148
# department               4.221675
# gender                   8.039409
# country                  2.995074
# city                     2.975369
# weight_kg                3.167488
# is_active                2.886700
# review                   7.216749
# price                    2.197044
# weight_kg_duplicate    100.000000
# target                   0.000000
# dtype: float64

# %%
df1=df.copy()

# %%
df.duplicated().sum()
# Out:
# 300

# %%
df.dtypes
# Out:
# employee_id              int64
# name                    object
# age                    float64
# salary                  object
# join_date               object
# department              object
# gender                  object
# country                 object
# city                    object
# weight_kg               object
# is_active               object
# review                  object
# price                   object
# weight_kg_duplicate    float64
# target                   int64
# dtype: object

# %%
df.head(10)
# Out:
#    employee_id        name    age  salary   join_date   department  gender  \
# 0        12369    Hasan D.  200.0   35149  2023-05-30        SALES     Man
# 1         7361    Grace P.    NaN   77836  2017-02-27  Engineering  FEMALE
# 2         3446      Eve D.   20.0   35404  2022-01-18           hr    male
# 3        18416    Diana E.   47.0  107375  2017-04-15    Marketing    Male
# 4        13677      Ira W.   64.0   55962  2021-11-02        SALES       F
# 5          458    Frank Y.   38.0   88527  2022-08-16     Mrketing    male
# 6        16484     John Q.   25.0  109079  2020-09-10           hr   Woman
# 7        12951  Charlie K.   22.0  $91118  2010-01-12       Finace       F
# 8        13108    Diana V.   43.0   88859  21/07/2016    Marketing    Male
# 9        14925    Alice C.    0.0   46627  2012-01-12        Sales  FEMALE
#
#           country        city weight_kg is_active  \
# 0         America      Sylhet     118.4         0
# ...
