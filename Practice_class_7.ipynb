# %%
import pandas as pd

# %%
df=pd.read_csv('students_120.csv')

# %%
df1=df.copy()

# %%
df
# Out:
#      StudentID        Name  Age Department  CGPA        City  Attendance  \
# 0         1001    Student1   18        CSE  2.70       Dhaka          70
# 1         1002    Student2   19        EEE  2.77  Chattogram          73
# 2         1003    Student3   20        BBA  2.84      Khulna          76
# 3         1004    Student4   21         ME  2.91    Rajshahi          79
# 4         1005    Student5   22         CE  2.98      Sylhet          82
# ..         ...         ...  ...        ...   ...         ...         ...
# 115       1116  Student116   18        CSE  2.89    Rajshahi          74
# 116       1117  Student117   19        EEE  2.96      Sylhet          77
# 117       1118  Student118   20        BBA  3.03    Barishal          80
# 118       1119  Student119   21         ME  3.10     Rangpur          83
# 119       1120  Student120   22         CE  3.17  Mymensingh          86
#
#      Marks  Scholarship  AdmissionYear
# 0     2000         True           2021
# ...

# %%
df.isnull().sum()
# Out:
# StudentID        0
# Name             0
# Age              0
# Department       0
# CGPA             0
# City             0
# Attendance       0
# Marks            0
# Scholarship      0
# AdmissionYear    0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# StudentID        0.0
# Name             0.0
# Age              0.0
# Department       0.0
# CGPA             0.0
# City             0.0
# Attendance       0.0
# Marks            0.0
# Scholarship      0.0
# AdmissionYear    0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StudentID      120 non-null    int64
#  1   Name           120 non-null    object
#  2   Age            120 non-null    int64
#  3   Department     120 non-null    object
#  4   CGPA           120 non-null    float64
#  5   City           120 non-null    object
#  6   Attendance     120 non-null    int64
#  7   Marks          120 non-null    int64
#  8   Scholarship    120 non-null    bool
#  9   AdmissionYear  120 non-null    int64
# dtypes: bool(1), float64(1), int64(5), object(3)
# memory usage: 8.7+ KB

# %%
num_cols=df.select_dtypes(include=['int64','float64']).columns
print(num_cols)
# Out:
# Index(['StudentID', 'Age', 'CGPA', 'Attendance', 'Marks', 'AdmissionYear'], dtype='object')

# %%
text_cols=df.select_dtypes(include=['object']).columns
print(text_cols)
# Out:
# Index(['Name', 'Department', 'City'], dtype='object')

# %%
df[num_cols]=df[num_cols].fillna(df[num_cols].median())

# %%
for col in text_cols:
    df[col]=df[col].fillna(df[col].mode()[0])

# %% [markdown]
# Task 3

# %%
q1=df['Marks'].quantile(0.25)
q3=df['Marks'].quantile(0.75)
iqr=q3-q1
lo=q1-1.5*iqr
h=q3+1.5*iqr
# outlier = df[(df['Marks'] < lo) | (df['Marks'] > h)]['Marks'].tolist()
mask = (df['Marks'] < lo) | (df['Marks'] > h)
outlier = df.loc[mask, 'Marks'].tolist()
print(outlier)
# Out:
# [2000, 800, 1000]

# %%
import numpy as np

# %%
df['Marks']=np.where(df['Marks']>h,h,
                    np.where(df['Marks']<lo,lo,
                    df['Marks']))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StudentID      120 non-null    int64
#  1   Name           120 non-null    object
#  2   Age            120 non-null    int64
#  3   Department     120 non-null    object
#  4   CGPA           120 non-null    float64
#  5   City           120 non-null    object
#  6   Attendance     120 non-null    int64
#  7   Marks          120 non-null    float64
#  8   Scholarship    120 non-null    bool
#  9   AdmissionYear  120 non-null    int64
# dtypes: bool(1), float64(2), int64(4), object(3)
# memory usage: 8.7+ KB

# %% [markdown]
# Task 5

# %%
df=df.drop_duplicates(subset='StudentID',keep='first')

# %%
jni
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 jni
#
# NameError: name 'jni' is not defined
